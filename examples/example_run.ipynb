# %%
from aethra import load_config, load_and_run
from aethra.pipeline import run_and_report

# %%
config = load_config("config.yaml")
input_file = ("example-data/*_W149.txt", "example-data/*_Z087.txt")
results = run_and_report(input_file, config)
# Out:
# Found 5 object(s) across paired filter files
#
# Pipeline complete — 5 object(s) processed.
#   veto_periodic:    0
#   veto_recurrent:   2
#   veto_chromatic:   0
#   is_variable_star: 2  (scan_candidate + any veto)
#   is_candidate:     3
#   is_ffp_candidate: 0

# %%
results
# Out:
#          name  is_candidate  is_ffp_candidate  is_variable_star  \
# 0  ulwdc1_010         False             False              True
# 1  ulwdc1_011         False             False              True
# 2  ulwdc1_012          True             False             False
# 3  ulwdc1_013          True             False             False
# 4  ulwdc1_014          True             False             False
#
#    veto_periodic  veto_recurrent  veto_chromatic is_achromatic  best_season  \
# 0          False            True           False          True            1
# 1          False            True           False          True            2
# 2          False           False           False          True            2
# 3          False           False           False           NaN            1
# 4          False           False           False          True            3
#
#    is_flat  ...  dof_flat  chi2_red_flat  bump_flag     bump_snr       t0_fit  \
# ...
